# %% [markdown]
# <a href="https://colab.research.google.com/github/jimmy-pink/colab-playground/blob/main/deeplearning-ai/Tensorflow-C4-TimeSeries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ⚜️ 《C4 Sequences&TimeSeries》

# %% [markdown]
# ![image.png](data:image/png;base64,...)
